# %% [markdown]
# # Processing Inhibitor Data
#
# ____

# %%
from pathlib import Path
current_dir = Path().resolve()
from microlive.imports import *
from microlive import microscopy as mi
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import inhibitors as INH

# %% [markdown]
# ## Data Configuration
# ___

# %%
# ── Data Path ─────────────────────────────────────────────
data_dir = one_drive_dir.joinpath(
    'General - Zhao (NZ) Lab/Gui RMS Analyses/Puro'
)

# ── Processing Parameters ─────────────────────────────────
inhibitor_frame_index = 4  # 0-indexed: frame when treatment was applied
use_sem = True
show_summary = True
show_individual_trajectories = False
max_percentage_threshold_after_treatment = None
threshold_percentage_for_runoff = 0.4
use_sigmoidal_fit = True
# ── Plotting Parameters ───────────────────────────────────
figsize = (8, 4)
ylims = (0, 1.4)
xlims = (-5, 6)
results_folder = None  # Set to a Path to save plots

# %% [markdown]
# ## HA Channel (pRS027)
# ___

# %%
substring_in_data_dir = 'pRS027'
selected_field = 'spot_int_ch_1'
plot_name = 'pRS027_HA'

responding_indices_pRS027_HA, frames_pRS027_HA, intensities_pRS027_HA, _, _, _, _ = INH.process_inhibitor_data(
    data_dir, inhibitor_frame_index, substring_in_data_dir, selected_field,
    use_sem, show_summary, max_percentage_threshold_after_treatment,
)

INH.plot_inhibitor(
    frames_pRS027_HA, intensities_pRS027_HA, inhibitor_frame_index,
    show_runoff_time=True,
    plot_name=plot_name,
    threshold_percentage_for_runoff=threshold_percentage_for_runoff,
    figsize=figsize,
    ylims=ylims,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       2 selected_field = 'spot_int_ch_1'
#       3 plot_name = 'pRS027_HA'
# ----> 5 responding_indices_pRS027_HA, frames_pRS027_HA, intensities_pRS027_HA, _, _, _, _ = INH.process_inhibitor_data(
#       6     data_dir, inhibitor_frame_index, substring_in_data_dir, selected_field,
#       7     use_sem, show_summary, max_percentage_threshold_after_treatment,
#       8 )
#      10 INH.plot_inhibitor(
#      11     frames_pRS027_HA, intensities_pRS027_HA, inhibitor_frame_index,
#      12     show_runoff_time=True,
#    (...)
#      16     ylims=ylims,
#      17 )
#
# File ~/Desktop/cof_paper/notebooks/Inhibitors/inhibitors.py:444, in process_inhibitor_data(data_dir, inhibitor_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, frame_rate_min, frame_interval_sec, simulation_dna_sequence, inhibitor_delay_time_seconds, list_tag_sequences, ki_simulation, ke_simulation, normalization_method, percentile_range, verbose)
#     390 """
#     391 Process inhibitor runoff experiment data.
#     392
#    (...)
#     440      list_simulation_parameters, time_array_sim_min, mean_intensity_ssa_inh, err_intensity_ssa_inh)
#     441 """
#     443 list_dataframes = []
# --> 444 subfolders = [folder for folder in data_dir.iterdir() if folder.is_dir()]
#     445 subfolders = [folder for folder in subfolders if 'results_' in folder.name and substring_in_data_dir in folder.name]
#     446 if verbose:
#
# File ~/Desktop/cof_paper/notebooks/Inhibitors/inhibitors.py:444, in <listcomp>(.0)
#     390 """
#     391 Process inhibitor runoff experiment data.
#     392
#    (...)
#     440      list_simulation_parameters, time_array_sim_min, mean_intensity_ssa_inh, err_intensity_ssa_inh)
#     441 """
#     443 list_dataframes = []
# --> 444 subfolders = [folder for folder in data_dir.iterdir() if folder.is_dir()]
#     445 subfolders = [folder for folder in subfolders if 'results_' in folder.name and substring_in_data_dir in folder.name]
#     446 if verbose:
#
# File /opt/anaconda3/envs/microlive/lib/python3.10/pathlib.py:1017, in Path.iterdir(self)
#    1013 def iterdir(self):
#    1014     """Iterate over the files in this directory.  Does not yield any
#    1015     result for the special paths '.' and '..'.
#    1016     """
# -> 1017     for name in self._accessor.listdir(self):
#    1018         if name in {'.', '..'}:
#    1019             # Yielding a path object for these makes little sense
#    1020             continue
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui RMS Analyses/Puro'

# %% [markdown]
# ## GFP Channel (pRS027)
# ___

# %%
substring_in_data_dir = 'pRS027'
selected_field = 'spot_int_ch_0'
plot_name = 'pRS027_GFP'

responding_indices_pRS027_GFP, frames_pRS027_GFP, intensities_pRS027_GFP, _, _, _, _ = INH.process_inhibitor_data(
    data_dir, inhibitor_frame_index, substring_in_data_dir, selected_field,
    use_sem, show_summary, max_percentage_threshold_after_treatment,
)

INH.plot_inhibitor(
    frames_pRS027_GFP, intensities_pRS027_GFP, inhibitor_frame_index,
    show_runoff_time=True,
    plot_name=plot_name,
    threshold_percentage_for_runoff=threshold_percentage_for_runoff,
    figsize=figsize,
    ylims=ylims,
)

# %% [markdown]
# ## Multi-Channel Comparison
# ___

# %%
INH.plot_multiple_inhibitors(
    [frames_pRS027_HA, frames_pRS027_GFP],
    [intensities_pRS027_HA, intensities_pRS027_GFP],
    inhibitor_frame_index,
    responding_indices_list=[responding_indices_pRS027_HA, responding_indices_pRS027_GFP],
    colors=['magenta', 'green'],
    legend_labels=['pRS027_HA', 'pRS027_GFP'],
    plot_name='HT_multi',
    threshold_percentage_for_runoff=-0.4,
    ylims = (0, 1.4),
    use_sigmoidal_fit=use_sigmoidal_fit,
    figsize=figsize,
    use_sem=use_sem,
    show_individual_trajectories=show_individual_trajectories,
)
