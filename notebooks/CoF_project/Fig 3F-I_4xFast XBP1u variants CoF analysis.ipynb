# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import sys
repo_root = Path().resolve().parents[1]  # Go up to cof_paper/
sys.path.insert(0, str(repo_root))
import utilities as ld
importlib.reload(ld)
# Out:
# <module 'utilities' from 'C:\\Users\\searsrh\\OneDrive - The University of Colorado Denver\\Desktop\\cof_paper\\utilities\\__init__.py'>

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data
        #RMS External Drive Location:    'E:/Co-translational folding (CoF) paper/CoF Analysis/Fig 3_4xFast XBP1u coTFT minitrack analysis'
        #Ning Zhao OneDrive Location:    '...General - Zhao (NZ) Lab/Zhao lab shared folder/Our papers/co-translational folding paper/Fig 3/3F-I_4xFast XBP1u CoF analysis/Fast XBP1u CoF analysis'

dataframes_dir = Path('E:/Co-translational folding (CoF) paper/CoF Analysis/Fig 3_4xFast XBP1u coTFT minitrack analysis')

# Average Folder Substrings

list_folder_substring_to_avoid = None


save_dir = current_dir.joinpath('results_Fig 3F-I_CoF')
save_dir.mkdir(parents=True, exist_ok=True)

# Individual day Folder Substrings
plot_individual_days = False     # Set to False to skip plotting individual experiment days and plot the overall average.

list_folder_substrings, list_names = ld.get_folder_substrings_and_names(
    dataframes_dir, 
    process_individual_days=plot_individual_days,
)
print(list_folder_substrings) #list for variant number in graphs below
print(list_names)
# Out:
# Found 3 plasmids in 75 folders
#   pRS038: 2 experiment(s)
#   pRS027: 2 experiment(s)
#   pRS048: 2 experiment(s)
# ['pRS027', 'pRS038', 'pRS048']
# ['4sfGFP-2mCh', '4sfGFP-2mCh-Xbp1', 'Xbp1-4sfGFP-2mCh']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,
            list_folder_substring_to_avoid,list_folder_substring_second_condition=None,
            show_file_names=True, verbose= False)
# Out:
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series001 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series001 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series002 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series002 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series003 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series003 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series004 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series005 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series005 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series006 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series007 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series007 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series008 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series008 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series009 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series010 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series010 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series012 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series012 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series013 (2 channels)
# Loaded results_20250822 pRS027_012_JF646 4hr tfx_Series013 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series014 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series015 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series016 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series017 (2 channels)
# Loaded results_20250818 pRS027_012_JF646 4hr tfx_Series018 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series001 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series001 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series002 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series002 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series003 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series003 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series004 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series004 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series005 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series006 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series007 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series007 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series007-1 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series008 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series009 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series010 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series011 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series011 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series012 (2 channels)
# Loaded results_20250708 pRS038_012_JF646 6hr tfx_Series013 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series013 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series014 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series015 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series015-1 (2 channels)
# Loaded results_20250822 pRS038_012_JF646 6hr tfx_Series016 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series001 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series002 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series003 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series004 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series005 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series007 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series008 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series009 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series010 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series011 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series012 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series013 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series014 (2 channels)
# Loaded results_20250815 pRS048_012_JF646 ON Tfx_Series015 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series001 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series003 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series004 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series005 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series006 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series008 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series009 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series010 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series011 (2 channels)
# Loaded results_20250708 pRS048_012_JF646 6hr tfx_Series013 (2 channels)

# %% [markdown]
# ## Plotting Configuration
# ___

# %%
# ── Plotting Configuration ─────────────────────────────────
PLOT_CONFIG = dict(
    figsize       = (4.5, 4),
    tick_size     = 12,
    swarm_color   = 'black',
    show_stats    = True,
    only_significant = True,
    max_percentile_significance = 99.5,
    cell_summary='median',  # each dot = np.nanmedian of all spots in that cell
)
SAVE_DIR = save_dir  # Defined in data config above; set to None to skip saving

# %% [markdown]
# ## Plotting data
# ___

# %%
# avg spots/frame in one cell. raw tracking rows divided by frame count.
ld.plot_swarm_plot(
    data_dict['average_number_spots'], list_names,
    y_label='Spots',
    title='Average Number Spots',
    #y_lim=(0, 300),
    plot_name='avg_spots',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
# unique trajectories in one cell. Trajectories >= 3 frames.
ld.plot_swarm_plot(
    data_dict['n_trajectories'], list_names,
    y_label='Trajectories',
    title='Number of Trajectories per Cell',
    y_lim=(0, 500),
    plot_name='n_trajectories',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Number of Trajectories per Cell'}, ylabel='Trajectories'>

# %% [markdown]
# ## Folding-colocalized

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0_coloc'], list_names,
    y_label='Intensity',
    title='Int Ch0 (Folding)-Coloc',
    y_lim=(-200, 4200),
    plot_name='int_ch0_coloc',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Int Ch0 (Folding)-Coloc'}, ylabel='Intensity'>

# %% [markdown]
# # Nascent Chain

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'], list_names,
    y_label='Intensity',
    title='Int Ch1 (Nascent Chains)',
    y_lim=(0, 2200),
    plot_name='int_ch1',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Int Ch1 (Nascent Chains)'}, ylabel='Intensity'>

# %% [markdown]
# ## Nascent chain-colocalized

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1_coloc'], list_names,
    y_label='Intensity',
    title='Int Ch1 (NCs)-Coloc',
    y_lim=(0, 2500),
    plot_name='int_ch1_coloc',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Int Ch1 (NCs)-Coloc'}, ylabel='Intensity'>

# %% [markdown]
# ## Nascent chain-not-colocalized

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1_not_coloc'], list_names,
    y_label='Intensity',
    title='Int Ch1 (NCs)-Not Coloc',
    y_lim=(0, 1500),
    plot_name='int_ch1_not_coloc',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Int Ch1 (NCs)-Not Coloc'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'], list_names,
    title='SNR Ch 0 (Folding)',
    y_label='SNR Channel 0',
    plot_name='snr_ch0',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'SNR Ch 0 (Folding)'}, ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'], list_names,
    title='SNR Ch 1 (NC)',
    y_label='SNR Channel 1',
    plot_name='snr_ch1',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'SNR Ch 1 (NC)'}, ylabel='SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'], list_names,
    y_label='Efficiency (%)',
    title='Efficiency (ML=0.51)',
    y_lim=(-10, 110),
    plot_name='efficiency_ml',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Efficiency (ML=0.51)'}, ylabel='Efficiency (%)'>

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_manual'], list_names,
    y_label='Efficiency (%)',
    title='Efficiency (Verification)',
    y_lim=(-10, 125),
    plot_name='efficiency_verification',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
    swarm_size=6,
)
# Out:
# <Axes: title={'center': 'Efficiency (Verification)'}, ylabel='Efficiency (%)'>
