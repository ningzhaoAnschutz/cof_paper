# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for 4xGFPq-2xmChq CoF Reporters

    # One Drive file path
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/...ADD PATH.../Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results')

    # External hard drive file path
dataframes_dir = Path (r'D:/Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results')


# Average Folder Substrings

# list_folder_substrings = ['pRS027', 'pRS032']
# list_folder_substring_to_avoid =    ['', '']
# list_names = ['4xsfGFPq-2xmChq', '4xmGFPuvq-2xmChq']


# Individual day Folder Substrings

list_folder_substrings = ['20250429 37C pRS027', '20250501 37C pRS027', '20250505 37C pRS027', '20250429 37C pRS032', '20250501 37C pRS032', '20250505 37C pRS032',]
list_folder_substring_to_avoid = None  #['', '', '', '', '']
list_names = ['4xsf Day 1', '4xsf Day 2', '4xsf Day 3', '4xuv Day 1', '4xuv Day 2', '4xuv Day 3']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : 20250429 37C pRS027
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series001
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series002
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series003
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series004
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series005
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series006
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series007
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series008
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series009
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series010
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series011
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series012
# Loaded results_20250429 37C pRS027_012_JF646_6hr tfx_Series013
# Data for column:  spot_int_ch_0
# Mean :    [761.15, 729.74, 792.29, 466.23, 906.76, 1415.39, 619.57, 864.75, 506.0, 663.59, 985.94, 720.52, 952.93]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  spot_int_ch_1
# Mean :    [2774.04, 1262.88, 1486.64, 851.48, 2534.65, 1919.48, 609.65, 1382.44, 563.95, 1028.4, 882.81, 1261.49, 1268.93]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  spot_size_ch_0
# Mean :    [3.09, 2.5, 2.5, 2.89, 2.79, 2.6, 2.6, 2.63, 2.56, 2.85, 2.52, 2.85, 2.48]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  spot_size_ch_1
# Mean :    [2.63, 2.7, 2.68, 2.75, 2.75, 2.87, 2.62, 2.58, 2.6, 2.67, 2.68, 2.6, 2.69]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  total_spot_int_ch_0
# Mean :    [95658.99, 53986.43, 45774.39, 34407.1, 103314.6, 110518.9, 40211.6, 76597.24, 30130.17, 49334.34, 77919.4, 62799.09, 72988.06]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  total_spot_int_ch_1
# Mean :    [134399.68, 69281.59, 66590.21, 38887.67, 109083.08, 97021.19, 26901.49, 64623.75, 27159.44, 47616.6, 46209.72, 51632.3, 65543.39]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  snr_ch_0
# Mean :    [0.82, 1.23, 1.69, 1.06, 1.06, 1.53, 1.41, 1.2, 1.28, 1.16, 1.33, 1.18, 1.44]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  snr_ch_1
# Mean :    [2.86, 2.05, 2.76, 2.25, 3.35, 2.53, 2.17, 2.48, 1.85, 2.34, 2.03, 2.98, 2.3]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  psf_amplitude_ch_0
# Mean :    [7474.92, 6280.77, 6016.25, 4435.03, 8315.41, 9920.1, 5334.9, 7425.21, 4173.61, 5432.39, 8455.38, 6418.1, 7378.65]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  psf_amplitude_ch_1
# Mean :    [11823.94, 6026.25, 6437.61, 4003.05, 10864.95, 7915.5, 3292.39, 6336.23, 3202.43, 4810.18, 4371.27, 5629.39, 5918.44]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.31, 1.06, 1.06, 1.23, 1.18, 1.11, 1.1, 1.12, 1.09, 1.21, 1.07, 1.21, 1.05]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.12, 1.15, 1.14, 1.17, 1.17, 1.22, 1.11, 1.09, 1.1, 1.13, 1.14, 1.1, 1.14]
# Number of spots:   [789, 3281, 1254, 884, 936, 2371, 405, 827, 1638, 855, 746, 424, 3878]
# -----------------------------------
# -----------------------------------
# Processing : 20250501 37C pRS027
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series001
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series002
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series003
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series004
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series005
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series007
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series008
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series009
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series010
# Loaded results_20250501 37C pRS027_012_JF646_6hr tfx_Series012
# Data for column:  spot_int_ch_0
# Mean :    [635.53, 855.46, 687.31, 838.34, 719.49, 1082.96, 1638.98, 1063.66, 994.73, 759.64]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  spot_int_ch_1
# Mean :    [1259.3, 890.63, 1069.26, 380.46, 440.17, 792.9, 1028.57, 1595.91, 797.72, 1852.18]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  spot_size_ch_0
# Mean :    [2.79, 2.53, 2.95, 2.98, 2.86, 2.45, 2.74, 2.93, 2.53, 2.71]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  spot_size_ch_1
# Mean :    [2.65, 2.75, 2.91, 2.79, 2.69, 2.52, 2.8, 2.82, 2.69, 2.91]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  total_spot_int_ch_0
# Mean :    [66304.16, 58955.23, 75908.21, 58814.32, 67525.3, 67744.07, 144666.52, 100793.18, 57668.27, 88776.06]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  total_spot_int_ch_1
# Mean :    [58168.72, 47370.83, 53207.45, 19328.35, 26889.68, 34568.39, 68637.7, 68425.65, 37026.95, 86118.94]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  snr_ch_0
# Mean :    [0.93, 1.38, 0.91, 1.22, 0.94, 1.59, 1.34, 1.18, 1.76, 1.03]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  snr_ch_1
# Mean :    [2.53, 1.95, 2.12, 1.39, 1.36, 2.27, 1.64, 2.71, 2.18, 2.96]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  psf_amplitude_ch_0
# Mean :    [6518.33, 6913.11, 6678.9, 6829.13, 6351.62, 8274.09, 11746.3, 8078.03, 7297.23, 7494.68]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  psf_amplitude_ch_1
# Mean :    [5930.17, 4521.26, 5095.57, 2418.97, 3006.11, 4010.37, 5610.58, 6595.82, 3943.67, 7561.66]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.18, 1.08, 1.25, 1.27, 1.21, 1.04, 1.16, 1.24, 1.07, 1.15]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.13, 1.17, 1.24, 1.18, 1.14, 1.07, 1.19, 1.2, 1.14, 1.23]
# Number of spots:   [1643, 3379, 1187, 1107, 1666, 427, 1612, 723, 1095, 572]
# -----------------------------------
# -----------------------------------
# Processing : 20250505 37C pRS027
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series005
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series009
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series011
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series012
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series013
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series014
# Loaded results_20250505 37C pRS027_012_JF646_6hr tfx_Series017
# Data for column:  spot_int_ch_0
# Mean :    [1215.63, 1533.66, 1180.34, 995.23, 1516.73, 1268.85, 724.83]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  spot_int_ch_1
# Mean :    [941.3, 808.05, 909.49, 1619.39, 1234.54, 1053.39, 1149.47]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  spot_size_ch_0
# Mean :    [3.02, 3.38, 2.9, 3.16, 3.04, 2.92, 2.82]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  spot_size_ch_1
# Mean :    [2.8, 2.9, 2.94, 2.78, 2.73, 2.66, 2.56]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  total_spot_int_ch_0
# Mean :    [113441.27, 144801.06, 121902.87, 136455.47, 214828.81, 128470.97, 136548.68]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  total_spot_int_ch_1
# Mean :    [40838.09, 38840.42, 47849.89, 69255.01, 65848.87, 55327.12, 56845.81]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  snr_ch_0
# Mean :    [1.19, 1.18, 1.01, 0.96, 1.03, 1.21, 0.81]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  snr_ch_1
# Mean :    [2.4, 1.98, 1.88, 3.17, 2.1, 2.04, 2.51]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  psf_amplitude_ch_0
# Mean :    [9169.64, 10447.56, 9542.83, 9072.63, 12251.83, 9825.5, 8808.6]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  psf_amplitude_ch_1
# Mean :    [4069.3, 3593.13, 4323.44, 7093.29, 5893.92, 5141.13, 5613.9]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.28, 1.44, 1.23, 1.34, 1.29, 1.24, 1.2]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.19, 1.23, 1.25, 1.18, 1.16, 1.13, 1.09]
# Number of spots:   [1262, 515, 579, 548, 1571, 2065, 834]
# -----------------------------------
# -----------------------------------
# Processing : 20250429 37C pRS032
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series001
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series002
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series003
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series004
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series005
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series007
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series008
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series009
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series010
# Loaded results_20250429 37C pRS032_012_JF646_6hr tfx_Series011
# Data for column:  spot_int_ch_0
# Mean :    [883.34, 1148.6, 556.31, 914.39, 1152.64, 592.92, 992.95, 1228.59, 635.31, 1366.48]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  spot_int_ch_1
# Mean :    [1069.9, 978.31, 879.57, 1655.32, 1410.43, 532.77, 524.99, 1536.14, 869.05, 3058.04]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  spot_size_ch_0
# Mean :    [4.01, 3.61, 3.57, 3.9, 3.56, 3.61, 3.32, 3.85, 3.36, 4.39]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  spot_size_ch_1
# Mean :    [3.57, 2.95, 2.65, 2.83, 2.97, 2.98, 2.71, 2.85, 3.1, 2.93]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  total_spot_int_ch_0
# Mean :    [136158.64, 118534.76, 64978.96, 250368.0, 150094.5, 62298.28, 50803.61, 148151.96, 72116.42, 320746.98]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  total_spot_int_ch_1
# Mean :    [60266.89, 50615.8, 39748.99, 90360.81, 76911.3, 32600.1, 22602.32, 82925.45, 39331.35, 177724.28]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  snr_ch_0
# Mean :    [0.62, 0.83, 0.67, 0.54, 0.85, 0.63, 0.92, 0.82, 0.69, 0.52]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  snr_ch_1
# Mean :    [1.82, 1.93, 2.27, 2.3, 2.15, 1.4, 1.96, 2.17, 2.26, 2.48]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  psf_amplitude_ch_0
# Mean :    [7624.63, 8370.13, 4786.94, 9509.92, 8779.25, 4944.37, 5686.89, 8667.34, 5440.43, 11302.79]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  psf_amplitude_ch_1
# Mean :    [5097.84, 4356.87, 4245.51, 7251.47, 5857.25, 3186.77, 2732.69, 6474.46, 4002.83, 11703.35]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.7, 1.54, 1.51, 1.66, 1.51, 1.53, 1.41, 1.63, 1.42, 1.86]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.52, 1.25, 1.13, 1.2, 1.26, 1.27, 1.15, 1.21, 1.32, 1.24]
# Number of spots:   [752, 1436, 449, 1530, 437, 1174, 403, 1546, 420, 946]
# -----------------------------------
# -----------------------------------
# Processing : 20250501 37C pRS032
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series002
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series003
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series004
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series005
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series006
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series008
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series010
# Loaded results_20250501 37C pRS032_012_JF646_6hr tfx_Series011
# Data for column:  spot_int_ch_0
# Mean :    [249.6, 491.98, 1090.5, 898.72, 1029.66, 512.32, 543.29, 729.56]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  spot_int_ch_1
# Mean :    [1582.49, 1745.27, 628.46, 1779.91, 3278.37, 1351.07, 2125.91, 1415.65]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  spot_size_ch_0
# Mean :    [4.04, 3.81, 3.52, 4.0, 3.79, 3.91, 4.47, 3.96]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  spot_size_ch_1
# Mean :    [2.55, 2.55, 2.68, 3.09, 2.81, 2.65, 2.78, 2.88]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  total_spot_int_ch_0
# Mean :    [122512.39, 113686.76, 82387.71, 181899.03, 196998.93, 85601.68, 253399.08, 209409.32]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  total_spot_int_ch_1
# Mean :    [63884.65, 79171.47, 33528.98, 117463.11, 164632.77, 58355.1, 96770.58, 88834.95]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  snr_ch_0
# Mean :    [0.24, 0.49, 1.08, 0.54, 0.62, 0.55, 0.32, 0.47]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  snr_ch_1
# Mean :    [3.41, 3.07, 1.79, 1.86, 2.89, 2.7, 2.87, 1.95]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  psf_amplitude_ch_0
# Mean :    [5134.18, 5987.53, 7426.81, 8101.14, 9283.47, 5393.13, 8330.57, 8764.73]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  psf_amplitude_ch_1
# Mean :    [7091.84, 7987.14, 3533.85, 7498.13, 12711.43, 5953.1, 8718.38, 6417.3]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.72, 1.62, 1.49, 1.7, 1.61, 1.66, 1.9, 1.68]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.08, 1.08, 1.14, 1.31, 1.19, 1.13, 1.18, 1.22]
# Number of spots:   [617, 1901, 1058, 3268, 1385, 1389, 1983, 2520]
# -----------------------------------
# -----------------------------------
# Processing : 20250505 37C pRS032
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series001
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series002
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series003
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series004
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series005
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series006
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series009
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series010
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series011
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series012
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series013
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series014
# Loaded results_20250505 37C pRS032_012_JF646_6hr tfx_Series015
# Data for column:  spot_int_ch_0
# Mean :    [1351.44, 955.88, 1046.07, 946.37, 1343.43, 1131.38, 546.07, 1071.44, 484.6, 988.01, 579.54, 709.36, 1644.57]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  spot_int_ch_1
# Mean :    [2103.49, 1119.18, 943.08, 1857.8, 727.78, 940.15, 449.85, 1863.72, 1241.02, 843.18, 854.61, 1058.75, 1243.66]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  spot_size_ch_0
# Mean :    [4.59, 3.99, 4.21, 4.62, 3.57, 3.72, 3.6, 3.79, 4.14, 3.89, 3.6, 3.88, 3.89]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  spot_size_ch_1
# Mean :    [2.9, 2.98, 2.92, 2.92, 2.67, 2.72, 2.6, 2.97, 2.85, 2.71, 2.85, 2.9, 2.78]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  total_spot_int_ch_0
# Mean :    [515855.11, 314490.96, 188682.81, 352767.02, 182366.9, 119974.32, 57888.46, 304193.27, 206846.51, 163851.45, 89242.09, 113175.69, 287518.12]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  total_spot_int_ch_1
# Mean :    [132432.38, 67086.0, 43551.82, 100731.37, 37959.8, 41416.0, 22664.99, 109426.64, 62012.76, 40414.57, 38530.03, 52514.43, 71145.8]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  snr_ch_0
# Mean :    [0.47, 0.49, 0.49, 0.4, 0.68, 0.88, 0.7, 0.56, 0.33, 0.6, 0.67, 0.55, 0.75]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  snr_ch_1
# Mean :    [2.11, 1.91, 2.11, 2.34, 1.83, 2.24, 1.67, 2.11, 2.27, 2.11, 2.3, 2.15, 1.95]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  psf_amplitude_ch_0
# Mean :    [13843.89, 11238.99, 8817.95, 11177.6, 9849.46, 7989.94, 5018.82, 11661.07, 8143.19, 8431.89, 5802.62, 6880.28, 12378.29]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  psf_amplitude_ch_1
# Mean :    [8947.36, 5073.09, 3909.91, 7686.67, 3770.52, 4119.04, 2827.28, 7843.22, 5693.73, 4140.17, 3992.72, 4930.81, 5861.89]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.95, 1.7, 1.79, 1.96, 1.52, 1.58, 1.53, 1.61, 1.76, 1.65, 1.53, 1.65, 1.65]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.23, 1.27, 1.24, 1.24, 1.13, 1.16, 1.11, 1.26, 1.21, 1.15, 1.21, 1.23, 1.18]
# Number of spots:   [2293, 2669, 708, 2874, 1223, 608, 1538, 4091, 514, 827, 947, 1383, 1061]
# -----------------------------------

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.7330
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.6426
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.4025
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.2103
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.5214
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.5362
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.1620
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.2743
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.8282
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 0.4173
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.0939
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.3114
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.0343
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 0.1003
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.4558
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    # figsize=(9, 5),
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0 (Folding)',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.3062
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.0063
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.2036
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.5466
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.1239
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.0553
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.7913
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.2031
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.6869
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 0.0702
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.0093
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.1348
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.0676
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 1.0000
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.0756
# <Axes: title={'center': 'Intensity Channel 0 (Folding)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1 (Nascent Chains)',
    # figsize=(9, 5),
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.1824
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.4378
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.6418
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.1403
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.3560
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.4747
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.5205
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.0343
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.4025
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 1.0000
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.0401
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.8773
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.0831
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 0.9753
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.0756
# <Axes: title={'center': 'Intensity Channel 1 (Nascent Chains)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.6418
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.0297
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.0001
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.0001
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.0000
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.2698
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.0002
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.0005
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.0001
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 0.0012
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.0037
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.0001
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.0343
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 0.0771
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.3363
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.1629
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.3929
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.0377
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.6970
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.0159
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.7396
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.9698
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.2031
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.7802
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 0.4747
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.6943
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.5880
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.1728
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 0.7802
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.1847
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"Efficiency (%)",
    title="CoF Efficiency (ML=0.5)",
    # figsize=(9, 5),
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(0, 100),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# Comparing 4xsf Day 1 vs 4xsf Day 2: p-value = 0.3685
# Comparing 4xsf Day 1 vs 4xsf Day 3: p-value = 0.0369
# Comparing 4xsf Day 1 vs 4xuv Day 1: p-value = 0.0001
# Comparing 4xsf Day 1 vs 4xuv Day 2: p-value = 0.0000
# Comparing 4xsf Day 1 vs 4xuv Day 3: p-value = 0.0000
# Comparing 4xsf Day 2 vs 4xsf Day 3: p-value = 0.3638
# Comparing 4xsf Day 2 vs 4xuv Day 1: p-value = 0.0002
# Comparing 4xsf Day 2 vs 4xuv Day 2: p-value = 0.0000
# Comparing 4xsf Day 2 vs 4xuv Day 3: p-value = 0.0001
# Comparing 4xsf Day 3 vs 4xuv Day 1: p-value = 0.0001
# Comparing 4xsf Day 3 vs 4xuv Day 2: p-value = 0.0003
# Comparing 4xsf Day 3 vs 4xuv Day 3: p-value = 0.0000
# Comparing 4xuv Day 1 vs 4xuv Day 2: p-value = 0.1457
# Comparing 4xuv Day 1 vs 4xuv Day 3: p-value = 0.1450
# Comparing 4xuv Day 2 vs 4xuv Day 3: p-value = 0.8044
# <Axes: title={'center': 'CoF Efficiency (ML=0.5)'}, ylabel='Efficiency (%)'>
