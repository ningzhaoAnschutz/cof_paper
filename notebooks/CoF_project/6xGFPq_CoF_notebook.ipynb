# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for 6xGFPq CoF Reporters

    # One Drive file path
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/...ADD PATH.../Co-translational folding (CoF) paper/6xGFPq/CoF_results')

    # External hard drive file path
dataframes_dir = Path (r'D:/Co-translational folding (CoF) paper/6xGFPq/CoF_results')


# Average Folder Substrings

list_folder_substrings = ['212', '370', '381'] #'222'
list_folder_substring_to_avoid =    ['', '', '' ]
list_names = ['6xsfGFPq', '6xmGFPuvq', '6xmChq'] #'6xmGFPwtq'


# Individual day Folder Substrings

# list_folder_substrings = ['20241119 pNZ212', '20241203 pNZ212', '20250314 6hr Tfx pNZ212', '20250109 pNZ222', '20241121 pNZ370', '20250114 6hr Tfx pNZ370']
# list_folder_substring_to_avoid =    ['', '', '', '', '', '' ]
# list_names = ['6xsf Day 1', '6xsf Day 2', '6xsf Day 3', '6xwt Day 1', '6xuv Day 1', '6xuv Day 2']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : 212
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series002
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series005
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series006
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series007
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series008
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series009
# Loaded results_20241203 pNZ212_367_JF646_4hr Tfx_Series013
# Loaded results_20250314 6hr Tfx pNZ212_pRS012 _6_JF646_Series004
# Loaded results_20250314 6hr Tfx pNZ212_pRS012 _6_JF646_Series005
# Loaded results_20250314 6hr Tfx pNZ212_pRS012 _6_JF646_Series009
# Loaded results_20250314 6hr Tfx pNZ212_pRS012 _6_JF646_Series010
# Loaded results_20250314 6hr Tfx pNZ212_pRS012 _6_JF646_Series014
# Loaded results_20241119 pNZ212_367_JF646_Series001
# Loaded results_20241119 pNZ212_367_JF646_Series002
# Loaded results_20241119 pNZ212_367_JF646_Series003
# Loaded results_20241119 pNZ212_367_JF646_Series006
# Data for column:  spot_int_ch_0
# Mean :    [1176.36, 1407.39, 538.74, 733.52, 703.94, 537.42, 701.17, 777.14, 431.71, 965.0, 683.21, 807.06, 700.45, 975.19, 906.27, 625.47]
# Number of spots:   [297, 1091, 501, 646, 520, 399, 912, 197, 666, 305, 339, 538, 474, 286, 1132, 1241]
# Data for column:  spot_int_ch_1
# Mean :    [1.17, 1.35, 1.1, 1.31, 1.13, 1.4, 1.25, 1.33, 1.25, 1.26, 1.48, 1.34, 1.19, 1.3, 1.09, 1.14]
# Number of spots:   [297, 1091, 501, 646, 520, 399, 912, 197, 666, 305, 339, 538, 474, 286, 1132, 1241]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.12, 1.25, 1.09, 1.16, 1.16, 1.19, 1.13, 1.35, 1.16, 1.24, 1.24, 1.19, 1.06, 1.12, 1.12, 1.2]
# Number of spots:   [297, 1091, 501, 646, 520, 399, 912, 197, 666, 305, 339, 538, 474, 286, 1132, 1241]
# -----------------------------------
# -----------------------------------
# Processing : 370
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series001
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series002
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series003
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series004
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series005
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series006
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series007
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series009
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series010
# Loaded results_20250114 6hr Tfx pNZ370_pRS0012 _6_JF646_Series011
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series003
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series004
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series005
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series006
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series007
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series008
# Loaded results_20241121 pNZ370_367_JF646 6hr tfx_Series009
# Data for column:  spot_int_ch_0
# Mean :    [152.01, 94.2, 205.91, 320.09, 563.72, 765.89, 68.24, 578.34, 91.57, 145.55, 231.05, 102.6, 440.4, 225.99, 345.71, 788.16, 507.62]
# Number of spots:   [592, 445, 814, 538, 731, 828, 529, 1135, 440, 1116, 1420, 1195, 1066, 1325, 876, 1694, 1308]
# Data for column:  spot_int_ch_1
# Mean :    [796.76, 275.43, 1757.2, 875.94, 833.21, 821.46, 729.45, 1065.05, 662.03, 730.26, 571.22, 569.02, 504.44, 346.89, 602.53, 836.3, 1076.77]
# Number of spots:   [592, 445, 814, 538, 731, 828, 529, 1135, 440, 1116, 1420, 1195, 1066, 1325, 876, 1694, 1308]
# Data for column:  spot_size_ch_0
# Mean :    [3.51, 3.25, 3.79, 3.34, 3.32, 3.23, 3.98, 3.37, 3.47, 3.87, 3.3, 3.65, 3.16, 3.11, 3.33, 3.54, 3.99]
# Number of spots:   [592, 445, 814, 538, 731, 828, 529, 1135, 440, 1116, 1420, 1195, 1066, 1325, 876, 1694, 1308]
# Data for column:  spot_size_ch_1
# Mean :    [2.75, 2.84, 2.6, 3.11, 2.54, 3.0, 2.74, 2.98, 3.1, 2.54, 2.59, 2.94, 2.82, 2.65, 2.67, 2.83, 2.64]
# Mean :    [-0.0, -0.12, 0.01, 0.02, -0.13, 0.0, 0.01, 0.03, 0.05, -0.04, 0.04, -0.02, 0.09, 0.06]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# Data for column:  snr_ch_1
# Mean :    [1.77, 1.55, 1.91, 1.81, 1.48, 1.47, 1.61, 1.66, 1.25, 1.62, 1.53, 1.57, 1.55, 1.85]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# Data for column:  psf_amplitude_ch_0
# Mean :    [3636.54, 5543.45, 3834.99, 5533.33, 4967.67, 3379.9, 5948.16, 3330.74, 3221.27, 6377.38, 2673.67, 5101.37, 3234.74, 2740.88]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# Data for column:  psf_amplitude_ch_1
# Mean :    [4632.94, 4510.81, 3894.39, 5572.07, 3568.58, 3644.54, 5119.28, 3156.93, 3363.59, 4938.83, 3693.27, 3191.86, 3271.29, 3850.38]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# Data for column:  psf_sigma_ch_0
# Mean :    [2.06, 1.92, 1.87, 2.06, 1.91, 1.9, 2.05, 1.87, 1.88, 2.06, 1.87, 1.9, 1.85, 1.99]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.12, 1.77, 1.19, 1.15, 1.57, 1.26, 1.28, 1.3, 1.36, 1.46, 1.28, 1.36, 1.35, 1.26]
# Number of spots:   [234, 659, 445, 296, 1147, 730, 2377, 875, 745, 1140, 1778, 310, 407, 689]
# -----------------------------------

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xsfGFPq vs 6xmGFPuvq: p-value = 0.0085
# Comparing 6xsfGFPq vs 6xmChq: p-value = 0.2530
# Comparing 6xmGFPuvq vs 6xmChq: p-value = 0.2337
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    # figsize=(9, 5),
    figsize=(7, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0 (Folding)',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xsfGFPq vs 6xmGFPuvq: p-value = 0.0001
# Comparing 6xsfGFPq vs 6xmChq: p-value = 0.0000
# Comparing 6xmGFPuvq vs 6xmChq: p-value = 0.0000
# <Axes: title={'center': 'Intensity Channel 0 (Folding)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1 (Nascent Chains)',
    # figsize=(9, 5),
    figsize=(7, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xsfGFPq vs 6xmGFPuvq: p-value = 0.0004
# Comparing 6xsfGFPq vs 6xmChq: p-value = 0.0000
# Comparing 6xmGFPuvq vs 6xmChq: p-value = 0.7358
# <Axes: title={'center': 'Intensity Channel 1 (Nascent Chains)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xsfGFPq vs 6xmGFPuvq: p-value = 0.0000
# Comparing 6xsfGFPq vs 6xmChq: p-value = 0.0000
# Comparing 6xmGFPuvq vs 6xmChq: p-value = 0.0000
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xsfGFPq vs 6xmGFPuvq: p-value = 0.0000
# Comparing 6xsfGFPq vs 6xmChq: p-value = 0.0057
# Comparing 6xmGFPuvq vs 6xmChq: p-value = 0.0058
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"Efficiency (%)",
    #title="CoF Efficiency (ML=0.5)",
    # figsize=(9, 5),
    figsize=(5, 6),
    tick_size=15,
    swarm_color="black",
    y_lim=(-10, 120),
    show_stats=False,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# <Axes: ylabel='Efficiency (%)'>
