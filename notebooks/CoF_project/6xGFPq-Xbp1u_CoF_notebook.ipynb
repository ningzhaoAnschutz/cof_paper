# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for 6xGFPq CoF Reporters
    # One Drive file path
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/Gui RMS Analyses/6xGFPq results')

 # External hard drive file path
dataframes_dir = Path (r'D:/Co-translational folding (CoF) paper/6xGFPq/CoF_results')


# Average Folder Substrings

# list_folder_substrings = ['212', '231', '222', '363']
# list_folder_substring_to_avoid =    ['', '', '','' ]
# list_names = ['6xsfGFPq', '6xsfGFPq-Xbp1u', '6xmGFPwtq', '6xmGFPwtq-Xbp1u',]

# Average SF Folder Substrings

# list_folder_substrings = ['212', '231']
# list_folder_substring_to_avoid =    ['', '' ]
# list_names = ['6xsfGFPq', '6xsfGFPq-Xbp1u']

# Average WT Folder Substrings

list_folder_substrings = ['222', '363']
list_folder_substring_to_avoid =    ['', '' ]
list_names = ['6xmGFPwtq', '6xmGFPwtq-Xbp1u',]


# Individual SF Day Folder Substrings

# list_folder_substrings = ['20241119 pNZ212', '20241203 pNZ212', '20250314 6hr Tfx pNZ212', '20241119 pNZ231', '20241203 pNZ231']
# list_folder_substring_to_avoid =    ['', '', '', '', '']
# list_names = ['6xsf Day 1', '6xsf Day 2', '6xsf Day 3', '6xsf-Xbp1u Day 1', '6xsf-Xbp1u Day 2']


# Individual WT Day Folder Substrings

# list_folder_substrings = ['20250109 pNZ222', '20241101 pNZ367_363']
# list_folder_substring_to_avoid =    ['', '' ]
# list_names = ['6xwt Day 1', '6xwt-Xbp1 Day 1']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : 222
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series002
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series003
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series004
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series005
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series006
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series007
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series008
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series009
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series010
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series011
# Loaded results_20250109 pNZ222 6hr Tfx_pRS012 _6_JF646_Series012
# Data for column:  spot_int_ch_0
# Mean :    [235.56, 34.29, 33.48, 182.11, 54.36, 113.59, 209.79, 54.43, 76.62, 587.39, 202.7]
# ...

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    # figsize=(9, 5),
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.8053
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    # figsize=(9, 5),
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0 (Folding)',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.2178
# <Axes: title={'center': 'Intensity Channel 0 (Folding)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1 (Nascent Chains)',
     # figsize=(9, 5),
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.4181
# <Axes: title={'center': 'Intensity Channel 1 (Nascent Chains)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.0054
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.7513
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"CoF Efficiency (%)",
    title="CoF Efficiency (ML=0.5)",
    # figsize=(9, 5),
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(150, 0),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# Comparing 6xmGFPwtq vs 6xmGFPwtq-Xbp1u: p-value = 0.0001
# <Axes: title={'center': 'CoF Efficiency (ML=0.5)'}, ylabel='CoF Efficiency (%)'>
