# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()

# Add repo root to path for utilities
import sys
repo_root = Path().resolve().parents[1]  # CoF_project -> notebooks -> cof_paper
sys.path.insert(0, str(repo_root))
import utilities as ld
importlib.reload(ld)
# Out:
# <module 'utilities' from '/Users/nzlab-la/Desktop/cof_paper/utilities/__init__.py'>

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for Dark mCherry Reporters
dataframes_dir = Path ('/Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Zhao lab shared folder/Our papers/co-translational folding paper/Fig 2/Fig 2_sf coTFT analysis')

# %%
process_individual_days = False

list_folder_substrings, list_names = ld.get_folder_substrings_and_names(
    dataframes_dir, 
    process_individual_days=process_individual_days,
)
print(list_folder_substrings)
print(list_names)
# Out:
# Found 7 plasmids in 134 folders
#   pRS030: 2 experiment(s)
#   pRS026: 2 experiment(s)
#   pNZ212: 3 experiment(s)
#   pRS027: 2 experiment(s)
#   pRS031: 2 experiment(s)
#   pRS029: 3 experiment(s)
#   pNZ381: 1 experiment(s)
# ['pNZ212', 'pRS026', 'pRS027', 'pRS029', 'pRS030', 'pRS031', 'pNZ381']
# ['6sGFP', '5sGFP-1mCh', '4sGFP-2mCh', '3sGFP-3mCh', '2sGFP-4mCh', '1sGFP-5mCh', '6mCh']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,
            list_folder_substring_to_avoid,list_folder_substring_second_condition=None,
            show_file_names=True, min_avg_spots_threshold=None,verbose = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,
# ----> 2             list_folder_substring_to_avoid,list_folder_substring_second_condition=None,
#       3             show_file_names=True, min_avg_spots_threshold=None,verbose = False)
#
# NameError: name 'list_folder_substring_to_avoid' is not defined

# %% [markdown]
# ## Plotting Configuration
# ___

# %%
# ── Plotting Configuration ─────────────────────────────────
PLOT_CONFIG = dict(
    figsize       = (7, 5),
    tick_size     = 10,
    swarm_color   = 'black',
    show_stats    = False,
    only_significant = True,
    max_percentile_significance = 100.0,
    x_tick_rotation = 45,
)

SAVE_DIR = None  # Set to current_dir / 'results' to save all plots

# %% [markdown]
# ## Plotting data
# ___

# %%
for key in data_dict.keys():
    print(key)
# Out:
# directories
# int_ch_0
# int_ch_1
# snr_ch_0
# snr_ch_1
# spot_size_ch_0
# spot_size_ch_1
# total_spot_int_ch_0
# total_spot_int_ch_1
# spot_amplitude_ch_0
# spot_amplitude_ch_1
# spot_sigma_ch_0
# spot_sigma_ch_1
# number_spots
# frames
# number_of_color_channels
# average_number_spots
# efficiency_ml
# efficiency_manual

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'], list_names,
    y_label='Spots',
    title='Average Number Spots',
    y_lim=(0, 300),
    plot_name='avg_spots',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'], list_names,
    y_label='Intensity Ch0 (Folding)',
    title='Intensity Channel 0',
    plot_name='int_ch0',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Intensity Channel 0'}, ylabel='Intensity Ch0 (Folding)'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'], list_names,
    y_label='Intensity Ch1 (Nascent Chains)',
    title='Intensity Channel 1',
    plot_name='int_ch1',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Intensity Channel 1'}, ylabel='Intensity Ch1 (Nascent Chains)'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'], list_names,
    y_label='SNR Channel 0',
    plot_name='snr_ch0',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'], list_names,
    y_label='SNR Channel 1',
    plot_name='snr_ch1',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: ylabel='SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plot_efficiency(
    data_dict['snr_ch_0'], data_dict['snr_ch_1'], list_names,
    y_label='Efficiency (%)',
    title='Efficiency SNR method',
    y_lim=(-5, 100),
    plot_name='snr_efficiency',
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, xlabel='Condition', ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'], list_names,
    y_label='Efficiency (%)',
    title='CoF Efficiency (ML=0.5)',
    y_lim=(-5, 100),
    plot_name='efficiency_ml',
    save_dir=SAVE_DIR,
    **PLOT_CONFIG,
)
# Out:
# <Axes: title={'center': 'CoF Efficiency (ML=0.5)'}, ylabel='Efficiency (%)'>

# %% [markdown]
# # plot an scatter plot of the efficiency of the CoF (ML=0.5) vs the Intensity Channel 0 (Folding)

# %%
# Exclude the last condition (6xmChq)
ld.plot_efficiency_vs_intensity_scatter_means(
    {key: val[:-1] for key, val in data_dict.items()},
    list_names[:-1],
    x_label='Folding Spot Intensity',
    y_label='CoF Efficiency (%)',
    figsize=PLOT_CONFIG['figsize'],
    tick_size=PLOT_CONFIG['tick_size'],
    marker_size=150,
    save_dir=SAVE_DIR,
    plot_name='intensity_efficiency',
)
# Out:
# <Axes: xlabel='Folding Spot Intensity', ylabel='CoF Efficiency (%)'>

# %%
ld.plot_efficiency_vs_intensity_scatter_means(
    data_dict,
    list_names[:-1],
    x_label='Mean Spot Intensity (Ch0)',
    y_label='CoF Efficiency (%)',
    figsize=PLOT_CONFIG['figsize'],
    tick_size=PLOT_CONFIG['tick_size'],
    marker_size=150,
    show_individual_cells=True,
    individual_cell_alpha=0.3,
    individual_cell_size=30,
)
# Out:
# <Axes: xlabel='Mean Spot Intensity (Ch0)', ylabel='CoF Efficiency (%)'>
