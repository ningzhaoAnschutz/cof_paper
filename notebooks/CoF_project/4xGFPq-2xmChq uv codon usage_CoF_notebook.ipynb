# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for 4xGFPq-2xmChq uv slow CoF Reporters

    # One Drive file path
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/...ADD PATH.../Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results_uv slow')
dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/Gui RMS Analyses/1111')

    # External hard drive file path
#dataframes_dir = Path (r'D:/Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results_uv slow')


# Average Folder Substrings

list_folder_substrings = ['pRS032','pRS045']
list_folder_substring_to_avoid = None  #['', '', '', '', '']
list_names = ['Opt', 'Deopt']


# Individual day Folder Substrings

#list_folder_substrings = ['20251111 pRS032', '20251111 pRS045']
#list_folder_substring_to_avoid = None  #['', '', '', '', '']
#list_names = ['32 Day 1', '45 Day 1']

#list_folder_substrings = ['20250827 37C pRS032', '20251111 pRS032', '20250625 pRS045', '20251111 pRS045']
#list_folder_substring_to_avoid = None  #['', '', '', '', '']
#list_names = ['32 Day 1', '32 Day 2', '45 Day 1', '45 Day 2']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : pRS032
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series001
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series002
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series002
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series003
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series003
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series004
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series004
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series005
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series006
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series006
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series007
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series008
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series008
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series009
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series01
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series010
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series011
# Loaded results_20251111 pRS032_12_JF646 6hr Tfx_Series011
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series012
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series013
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series013-1
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series014
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series007
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series008
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series009
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series010
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series011
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series012
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series013
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series014
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series015
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series016
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series017
# Loaded results_20251111 pRS045_12_JF646 6hr Tfx_Series018
# Data for column:  spot_int_ch_0
# Mean :    [194.26, 16.84, 54.84, 7.56, 7.48, 19.99, 484.27, 55.79, -1.78, -249.69, 6.95, -184.18, 59.08, -84.97, 22.96, 56.42, 175.64, -34.65, 320.14, 33.62, 71.1, -16.11]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  spot_int_ch_1
# Mean :    [360.53, 689.04, 327.11, 319.68, 608.65, 330.47, 563.02, 379.08, 914.34, 1324.98, 717.07, 826.13, 446.44, 592.63, 430.31, 1080.19, 697.51, 616.55, 974.68, 396.69, 505.26, 507.89]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  spot_size_ch_0
# Mean :    [4.7, 4.82, 4.64, 4.17, 4.66, 4.35, 4.09, 4.21, 5.16, 5.1, 4.76, 4.76, 4.62, 4.7, 4.17, 4.97, 4.49, 4.12, 4.11, 4.32, 4.43, 4.51]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  spot_size_ch_1
# Mean :    [2.49, 3.31, 2.55, 2.3, 3.19, 2.41, 2.43, 3.08, 2.93, 4.15, 2.63, 4.29, 3.57, 4.09, 2.98, 3.01, 3.05, 2.81, 3.09, 2.77, 2.79, 3.34]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  total_spot_int_ch_0
# Mean :    [184629.73, 176328.35, 175288.11, 68141.29, 151616.34, 76728.63, 97952.29, 61904.32, 510841.39, 563712.66, 122516.63, 383468.02, 130772.96, 308384.42, 32559.98, 419450.28, 130244.94, 230720.4, 168793.41, 54679.41, 102049.42, 86863.75]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  total_spot_int_ch_1
# Mean :    [23856.11, 41532.85, 21014.12, 17347.62, 46095.18, 19056.74, 28864.1, 21731.65, 63699.72, 95292.84, 38025.44, 78878.39, 36574.24, 61130.81, 25025.44, 77265.48, 37146.63, 38031.2, 48328.72, 23729.43, 34058.59, 34064.5]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  snr_ch_0
# Mean :    [0.15, 0.01, 0.05, 0.02, 0.02, 0.04, 0.49, 0.12, 0.01, -0.07, 0.01, -0.08, 0.04, -0.07, 0.07, 0.03, 0.18, -0.01, 0.27, 0.07, 0.09, -0.01]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  snr_ch_1
# Mean :    [1.24, 1.61, 1.25, 1.39, 1.31, 1.4, 1.77, 1.27, 1.63, 1.58, 1.94, 1.21, 1.06, 1.07, 1.55, 1.67, 1.89, 1.67, 1.95, 1.44, 1.35, 1.4]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  psf_amplitude_ch_0
# Mean :    [6409.28, 5531.69, 5727.04, 2970.27, 4652.26, 3454.99, 5560.16, 2816.22, 9959.16, 11512.77, 3845.78, 8008.48, 4553.91, 7095.44, 1879.6, 8487.22, 4841.53, 5961.96, 6079.62, 2692.46, 3781.45, 3348.88]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  psf_amplitude_ch_1
# Mean :    [2929.84, 3604.16, 2690.25, 2612.33, 3834.64, 2571.74, 3474.83, 2490.4, 4887.52, 5755.1, 3978.73, 4516.8, 3026.8, 3473.38, 2715.92, 5628.47, 3484.69, 3672.03, 4433.6, 2741.01, 3512.77, 3130.92]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  psf_sigma_ch_0
# Mean :    [2.0, 2.05, 1.97, 1.77, 1.98, 1.85, 1.74, 1.79, 2.19, 2.17, 2.02, 2.02, 1.96, 2.0, 1.77, 2.11, 1.91, 1.75, 1.75, 1.83, 1.88, 1.91]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.06, 1.41, 1.08, 0.98, 1.36, 1.02, 1.03, 1.31, 1.25, 1.76, 1.12, 1.82, 1.52, 1.74, 1.27, 1.28, 1.3, 1.19, 1.31, 1.18, 1.19, 1.42]
# Number of spots:   [729, 345, 787, 407, 2260, 495, 1875, 596, 2324, 770, 732, 1230, 690, 1540, 843, 963, 971, 640, 690, 1476, 1716, 1024]
# -----------------------------------

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing Opt vs Deopt: p-value = 0.8116
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    # figsize=(9, 5),
    figsize=(7, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0 (Folding)',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing Opt vs Deopt: p-value = 0.0000
# <Axes: title={'center': 'Intensity Channel 0 (Folding)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1 (Nascent Chains)',
    # figsize=(9, 5),
    figsize=(3, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=False,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Intensity Channel 1 (Nascent Chains)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing Opt vs Deopt: p-value = 0.0000
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing Opt vs Deopt: p-value = 0.0000
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"Efficiency (%)",
    #title="CoF Efficiency (ML=0.5)",
    #figsize=(9, 5),
    figsize=(3, 3),
    tick_size=10,
    swarm_color="black",
    y_lim=(-10, 100),
    show_stats=False,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# <Axes: ylabel='Efficiency (%)'>
