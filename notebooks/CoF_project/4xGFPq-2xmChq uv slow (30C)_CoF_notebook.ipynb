# %% [markdown]
# # Comparing Data Sets.
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for 4xGFPq-2xmChq uv slow CoF Reporters

    # One Drive file path
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/...ADD PATH.../Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results_uv slow')

    # External hard drive file path
dataframes_dir = Path (r'D:/Co-translational folding (CoF) paper/4xGFPq-2xmChq/CoF_results_uv slow')


# Average Folder Substrings

list_folder_substrings = ['37C pRS032','30C pRS032']
list_folder_substring_to_avoid = None  #['', '', '', '', '']
list_names = ['uv (37C)', 'uv (30C)']


# Individual day Folder Substrings

#list_folder_substrings = ['20250825 37C pRS032', '20250827 37C pRS032', '20250516 30C pRS032', '20250910 30C pRS032']
#list_folder_substring_to_avoid = None  #['', '', '', '', '']
#list_names = ['uv Day 1', 'uv Day 2', 'uv 30C Day 1', 'uv 30C Day 2']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : 37C pRS032
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series001
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series001
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series002
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series003
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series003
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series004
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series004
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series006
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series006
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series006-1
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series007
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series007
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series008
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series008
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series009
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series009
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series010
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series011
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series011
# Loaded results_20250825 37C pRS032_012_JF646 4hr Tfx_Series012
# Loaded results_20250827 37C pRS032_012_JF646 6hr Tfx_Series012
# Mean :    [1.06, 1.07, 1.04, 1.16, 1.1, 1.23, 1.14, 1.27, 1.1, 1.48, 1.17, 1.12, 1.1, 1.09, 1.06, 1.06, 1.17, 1.18, 1.09, 1.24, 1.25, 1.07, 1.06, 1.14, 1.09]
# Number of spots:   [663, 1625, 1591, 373, 310, 896, 902, 322, 1729, 733, 418, 1643, 1117, 684, 1421, 967, 1256, 1952, 1699, 2148, 712, 574, 401, 1275, 795]
# -----------------------------------
# -----------------------------------
# Processing : 30C pRS032
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series002
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series003
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series005
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series006
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series008
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series009
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series010
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series012
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series014
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series016
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series017
# Loaded results_20250910 30C pRS032_012_JF646 10hr Tfx_Series018
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series001
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series002
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series003
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series004
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series005
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series007
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series008
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series009
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series010
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series011
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series011-1
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series012
# Loaded results_20250516 30C pRS032_012_JF646_6hr tfx_Series013
# Data for column:  spot_int_ch_0
# Mean :    [3759.57, 4001.83, 3889.39, 1159.92, 1326.69, 2068.45, 1077.69, 2997.59, 2903.0, 555.69, 2358.02, 2277.61, 1796.36, 2880.52, 1723.01, 1057.0, 1081.86, 1120.25, 1056.91, 574.44, 1371.24, 1333.36, 4473.92, 1807.78, 2245.77]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# Data for column:  spot_int_ch_1
# Mean :    [2697.75, 3746.43, 2519.62, 1384.46, 983.67, 3389.82, 1354.24, 3245.34, 3648.24, 1077.83, 2594.14, 1265.82, 2478.65, 3592.5, 2488.59, 1361.24, 5172.23, 1307.54, 2085.72, 4093.01, 2891.11, 1582.04, 3091.71, 5587.32, 4843.8]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# Data for column:  psf_amplitude_ch_0
# Mean :    [15491.29, 20780.29, 20486.75, 8410.17, 9247.57, 13157.72, 6959.32, 18738.65, 16188.9, 6167.73, 15420.95, 10937.13, 10219.8, 13750.55, 9626.94, 7390.46, 11243.8, 8221.19, 7444.26, 7680.84, 9362.71, 8491.17, 18195.5, 13336.51, 13972.79]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# Data for column:  psf_amplitude_ch_1
# Mean :    [9887.49, 14127.71, 10101.51, 7007.04, 4726.17, 14667.62, 5953.18, 13550.62, 14321.28, 6810.21, 11601.76, 5488.45, 10086.01, 14026.86, 9789.7, 5783.54, 21966.26, 6459.58, 8954.56, 17014.71, 11506.91, 6554.33, 11880.69, 20774.08, 18554.6]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.57, 1.47, 1.71, 1.2, 1.22, 1.51, 1.36, 1.42, 1.77, 1.51, 1.37, 1.3, 1.23, 1.26, 1.28, 1.3, 1.52, 1.21, 1.18, 1.51, 1.34, 1.25, 1.36, 1.47, 1.26]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.28, 1.22, 1.57, 1.05, 1.13, 1.1, 1.14, 1.13, 1.3, 1.1, 1.17, 1.18, 1.12, 1.1, 1.16, 1.15, 1.08, 1.07, 1.09, 1.16, 1.15, 1.21, 1.12, 1.27, 1.2]
# Number of spots:   [406, 556, 2046, 502, 2191, 1034, 1662, 442, 917, 474, 1891, 1289, 519, 590, 507, 831, 627, 924, 802, 1558, 1135, 1278, 740, 1968, 1104]
# -----------------------------------

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    figsize=(8, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing uv (37C) vs uv (30C): p-value = 0.9536
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    # figsize=(9, 5),
    figsize=(7, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0 (Folding)',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing uv (37C) vs uv (30C): p-value = 0.0000
# <Axes: title={'center': 'Intensity Channel 0 (Folding)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1 (Nascent Chains)',
    # figsize=(9, 5),
    figsize=(7, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing uv (37C) vs uv (30C): p-value = 0.0000
# <Axes: title={'center': 'Intensity Channel 1 (Nascent Chains)'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing uv (37C) vs uv (30C): p-value = 0.0000
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing uv (37C) vs uv (30C): p-value = 0.0000
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"Efficiency (%)",
    #title="CoF Efficiency (ML=0.5)",
    # figsize=(9, 5),
    figsize=(3, 4),
    tick_size=10,
    swarm_color="black",
    y_lim=(-10, 120),
    show_stats=False,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# <Axes: ylabel='Efficiency (%)'>
