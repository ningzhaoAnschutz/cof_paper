# %% [markdown]
# # Comparing Data Sets
# ____

# %%
from pathlib import Path
from microlive.imports import *
from microlive import microscopy as mi
current_dir = Path().resolve()
parent_dir = current_dir.parents[1]
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import load_data as ld
# Out:
# WARNING:root:openblas_set_num_threads not found
# Model loaded to cpu.

# %% [markdown]
# ## Loading data and strings for subclassification
# ___

# %%
# Loading data for Dark mCherry Reporters
# dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/Gui Analyses/CoF/Dark mCherry Reporters')
# list_folder_substrings = ['pRS026_pRS012', 'pRS027_pRS012', 'pRS029_pRS012', 'pRS030_pRS012', 'pRS031_pRS012']
# list_folder_substring_to_avoid = None  #['', '', '', '', '']
# list_names = ['pRS026', 'pRS027', 'pRS029', 'pRS030', 'pRS031']

# %%
dataframes_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/Gui Analyses/Temps')
list_folder_substrings = ['30C', '37C', '37 to 30C']
list_folder_substring_to_avoid = ['37 to 30C', '37 to 30C', '' ] # use  ['', '', '' ]
list_names = ['30C', '37C', '37 to 30C']

# %% [markdown]
# ## Loading the data
# ____

# %%
data_dict = ld.aggregate_folder_data(dataframes_dir,list_folder_substrings,list_folder_substring_to_avoid,list_folder_substring_second_condition=None,show_file_names=True)
# Out:
# -----------------------------------
# Processing : 30C
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series001_cell_1
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series001_cell_2
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series002_cell_1
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series002_cell_2
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series003
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series004_cell_1
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series004_cell_2
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series005
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series006
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series007
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series008
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series009
# Loaded results_20250410 U2OS-pRS012_pNZ370_30C_ON_JF646_Dox_Series011
# Loaded results_20250318 30C 8hr Tfx pNZ370_pRS012 _6_JF646_Series002
# Loaded results_20250318 30C 8hr Tfx pNZ370_pRS012 _6_JF646_Series003
# Loaded results_20250318 30C 8hr Tfx pNZ370_pRS012 _6_JF646_Series004
# Data for column:  psf_amplitude_ch_1
# Mean :    [3610.61, 5557.27, 4284.17, 2036.5, 5503.32, 7994.06, 6282.37, 4932.02, 5007.73, 3885.94, 3797.39, 3795.58, 4777.06, 6329.67, 5148.45, 5105.0, 2692.42, 3602.52, 3152.8, 5891.46, 3922.13, 5083.63, 2353.96, 3815.79, 5813.99, 6763.42, 3679.05, 2719.96, 3005.76, 2356.87, 3172.22, 4155.37, 5429.93]
# Number of spots:   [690, 451, 1639, 237, 1505, 800, 577, 324, 496, 588, 484, 582, 1310, 1704, 496, 814, 1101, 881, 472, 311, 1129, 2683, 883, 314, 2420, 2335, 1189, 1538, 1023, 898, 873, 1818, 1317]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.5, 1.34, 1.52, 1.33, 1.66, 1.61, 1.63, 1.41, 1.38, 1.41, 1.59, 1.69, 1.61, 1.53, 1.63, 1.44, 1.6, 1.56, 1.45, 1.61, 1.65, 1.53, 1.5, 1.39, 1.57, 1.52, 1.4, 1.53, 1.33, 1.3, 1.4, 1.52, 1.69]
# Number of spots:   [690, 451, 1639, 237, 1505, 800, 577, 324, 496, 588, 484, 582, 1310, 1704, 496, 814, 1101, 881, 472, 311, 1129, 2683, 883, 314, 2420, 2335, 1189, 1538, 1023, 898, 873, 1818, 1317]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.15, 1.08, 1.11, 1.28, 1.08, 1.1, 1.14, 1.34, 1.07, 1.36, 1.11, 1.19, 1.13, 1.19, 1.05, 1.34, 1.09, 1.11, 1.31, 1.13, 1.08, 1.23, 1.11, 1.39, 1.06, 1.08, 1.09, 1.26, 1.19, 1.15, 1.11, 1.22, 1.12]
# Number of spots:   [690, 451, 1639, 237, 1505, 800, 577, 324, 496, 588, 484, 582, 1310, 1704, 496, 814, 1101, 881, 472, 311, 1129, 2683, 883, 314, 2420, 2335, 1189, 1538, 1023, 898, 873, 1818, 1317]
# -----------------------------------
# -----------------------------------
# Processing : 37 to 30C
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series001
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series002
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series003
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series004
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series005
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series006
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series007
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series008
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series009
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series010
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series011
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series012
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series013
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series014
# Loaded results_202504011 37 to 30C ON Tfx pNZ370_pRS012 _6_JF646_Series015
# Data for column:  spot_int_ch_0
# Mean :    [1199.03, 1006.35, 881.72, 478.31, 213.57, 508.9, 588.1, 694.23, 429.9, 1094.43, 1469.26, 1052.72, 1385.1, 535.34, 460.4]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  spot_int_ch_1
# Mean :    [2276.38, 1149.13, 1314.29, 1740.08, 1227.09, 2262.23, 4060.36, 1872.71, 1367.62, 2844.05, 4195.9, 4645.97, 4448.06, 912.45, 970.0]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  spot_size_ch_0
# Mean :    [3.4, 3.25, 3.55, 4.16, 3.85, 4.05, 4.34, 3.95, 3.66, 3.13, 3.26, 4.01, 3.61, 3.44, 3.34]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  spot_size_ch_1
# Mean :    [2.77, 2.59, 2.78, 3.16, 2.94, 3.08, 3.17, 3.15, 3.03, 2.71, 2.9, 2.91, 2.72, 2.76, 2.84]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  total_spot_int_ch_0
# Mean :    [64859.81, 54312.11, 61140.93, 81824.22, 36559.29, 85009.94, 155910.34, 81968.28, 47747.44, 73292.35, 100898.43, 115713.44, 137701.75, 45726.92, 33474.34]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  total_spot_int_ch_1
# Mean :    [107959.23, 50698.21, 72373.87, 141339.8, 79391.55, 177982.87, 307060.96, 132046.39, 96327.87, 135744.0, 188648.8, 279788.13, 278797.89, 54080.72, 52422.67]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  snr_ch_0
# Mean :    [1.44, 1.16, 1.02, 0.52, 0.33, 0.48, 0.41, 0.64, 0.67, 1.24, 1.71, 0.84, 0.9, 0.68, 0.71]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  snr_ch_1
# Mean :    [2.81, 2.33, 2.26, 1.76, 1.77, 1.95, 2.07, 1.87, 1.82, 2.97, 3.2, 2.73, 2.47, 1.87, 1.9]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  psf_amplitude_ch_0
# Mean :    [7377.36, 6247.26, 6095.04, 4682.39, 3066.74, 4863.76, 7147.41, 5754.06, 4219.4, 6943.47, 8938.07, 7223.53, 9037.72, 4424.88, 3826.13]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  psf_amplitude_ch_1
# Mean :    [9266.58, 5567.59, 6194.72, 7515.7, 5625.73, 9366.71, 16054.77, 7534.38, 6069.54, 11111.48, 15716.76, 17438.9, 17952.23, 4475.4, 4468.18]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  psf_sigma_ch_0
# Mean :    [1.44, 1.38, 1.51, 1.77, 1.63, 1.72, 1.84, 1.68, 1.56, 1.33, 1.38, 1.7, 1.53, 1.46, 1.42]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# Data for column:  psf_sigma_ch_1
# Mean :    [1.18, 1.1, 1.18, 1.34, 1.25, 1.31, 1.35, 1.34, 1.29, 1.15, 1.23, 1.24, 1.15, 1.17, 1.21]
# Number of spots:   [1277, 351, 1706, 1013, 1582, 1983, 1333, 1543, 1375, 456, 342, 1238, 713, 1416, 710]
# -----------------------------------

# %% [markdown]
# ## Plotting data
# ___

# %%
ld.plot_swarm_plot(
    data_dict['average_number_spots'],
    list_names,
    x_label="",
    y_label="Spots",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title =  "Average Number Spots",
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0405
# Comparing 30C vs 37 to 30C: p-value = 0.0132
# Comparing 37C vs 37 to 30C: p-value = 0.3277
# <Axes: title={'center': 'Average Number Spots'}, ylabel='Spots'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_0'],
    list_names,
    x_label="",
    y_label='Intensity',
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    title = 'Intensity Channel 0',
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0000
# Comparing 30C vs 37 to 30C: p-value = 0.0005
# Comparing 37C vs 37 to 30C: p-value = 0.0041
# <Axes: title={'center': 'Intensity Channel 0'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['int_ch_1'],
    list_names,
    x_label="",
    y_label='Intensity',
    title = 'Intensity Channel 1',
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0000
# Comparing 30C vs 37 to 30C: p-value = 0.7881
# Comparing 37C vs 37 to 30C: p-value = 0.0000
# <Axes: title={'center': 'Intensity Channel 1'}, ylabel='Intensity'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_0'],
    list_names,
    x_label="",
    y_label= "SNR Channel 0",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0008
# Comparing 30C vs 37 to 30C: p-value = 0.3392
# Comparing 37C vs 37 to 30C: p-value = 0.0558
# <Axes: ylabel='SNR Channel 0'>

# %%
ld.plot_swarm_plot(
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label=" SNR Channel 1",
    title="",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
    only_significant=True,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0000
# Comparing 30C vs 37 to 30C: p-value = 0.0143
# Comparing 37C vs 37 to 30C: p-value = 0.2857
# <Axes: ylabel=' SNR Channel 1'>

# %% [markdown]
# ## Calculating Folding Efficiency SNR method.
#
# ___

# %%
ld.plot_swarm_plo_efficiency(
    data_dict['snr_ch_0'],
    data_dict['snr_ch_1'],
    list_names,
    x_label="",
    y_label= "Efficiency (%)",
    title="Efficiency SNR method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 99.5,
    save_dir=None,
    plot_name= "SNR Efficiency",
    threshold_ch0=0.5,
    threshold_ch1=0.1,
    only_significant=True,
)
# Out:
# <Axes: title={'center': 'Efficiency SNR method'}, ylabel='Efficiency (%)'>

# %% [markdown]
# ## Calculating Folding Efficiency using ML method
#
# ___

# %%
ld.plot_swarm_plot(
    data_dict['efficiency_ml'],
    list_names,
    x_label="",
    y_label=r"Efficiency (%)",
    title="Efficiency ML method",
    figsize=(5, 5),
    tick_size=10,
    swarm_color="black",
    #y_lim=(1, 5.5),
    show_stats=True,
    max_percentile_significance = 100.0,
    save_dir=None,
    plot_name= None,
)
# Out:
# Comparing 30C vs 37C: p-value = 0.0002
# Comparing 30C vs 37 to 30C: p-value = 0.5503
# Comparing 37C vs 37 to 30C: p-value = 0.0000
# <Axes: title={'center': 'Efficiency ML method'}, ylabel='Efficiency (%)'>
