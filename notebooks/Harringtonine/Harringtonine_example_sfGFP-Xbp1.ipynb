# %% [markdown]
# # Processing Harringtonine Data
#
# ____

# %%
from pathlib import Path
current_dir = Path().resolve()
from microlive.imports import *
from microlive import microscopy as mi
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import Harringtonine as HT
one_drive_dir
# Out:
# WindowsPath('C:/Users/searsrh/OneDrive - The University of Colorado Denver')

# %%
# Define the parameters
data_dir = Path (r'C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop')

results_folder = None
harringtonine_frame_index = 5
substring_in_data_dir = 'pNZ212' # pNZ212 pNZ231
selected_field = 'spot_int_ch_1' #'spot_int_ch_0' "spot_int_ch_1'
plot_name = 'pNZ212'
use_sem = True
show_individual_trajectories = False
show_summary = True
max_percentage_threshold_after_treatment = None  
threshold_percentage_for_runoff = 0.4
# Call the function and plotting
responding_indices,frames_experimental_min_recentered, intensities_normalized, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered, intensities_normalized, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff, figsize=(8,5))
# Out:
# List of processed dataframes:
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ212_pNN010_JF646_TileScan 1_Cell 1
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ212_pNN010_JF646_TileScan 1_Cell 5
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ212_pNN010_JF646_TileScan 1_Cell 7
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ212_pNN010_JF646_TileScan 1_Cell 8
# ...
# ---------Summary: ----------
#
# ----------Cells------------
# total_cells:  4
# number_of_responding_cells:  4
# number_of_non_responding_cells:  0
# percentage_non_responding_cells:  0.0
#
# ----------RNA------------
# average_total_molecules_before_treatment:  312.6
# average_molecules_before_treatment_responding:  312.6
# ...

# %%
# Define the parameters
data_dir = Path (r'C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop')

results_folder = None
harringtonine_frame_index = 5
substring_in_data_dir = 'pNZ231' # pNZ212 pNZ231
selected_field = 'spot_int_ch_0' #'spot_int_ch_0' "spot_int_ch_1'
plot_name = 'pNZ231'
use_sem = True
show_individual_trajectories = False
show_summary = True
max_percentage_threshold_after_treatment = None  
threshold_percentage_for_runoff = 0.4
# Call the function and plotting
responding_indices,frames_experimental_min_recentered, intensities_normalized, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered, intensities_normalized, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff, figsize=(8,5))
# Out:
# List of processed dataframes:
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 12
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 4
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 4-2
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 6
# subfolder: C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop\results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 9
# ...
# ---------Summary: ----------
#
# ----------Cells------------
# total_cells:  5
# number_of_responding_cells:  5
# ...
