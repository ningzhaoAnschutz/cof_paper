# %% [markdown]
# # Processing Harringtonine Data
#
# ____

# %%
from pathlib import Path
current_dir = Path().resolve()
from microlive.imports import *
from microlive import microscopy as mi
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import Harringtonine as HT
one_drive_dir
# Out:
# WindowsPath('C:/Users/searsrh/OneDrive - The University of Colorado Denver')

# %%
    # Define the parameters

#data_dir = one_drive_dir.joinpath('H') # desktop path

#data_dir = one_drive_dir.joinpath(r'C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop')


    # External hard drive file path

data_dir = Path (r'D:/Co-translational folding (CoF) paper/4xGFPq-2xmChq/sf_Har')




results_folder = None
harringtonine_frame_index = 5 # starting to count from 0, so 5 means 6th frame
substring_in_data_dir = 'pRS027' # pRS027, pRS038 , pRS048
selected_field = 'spot_int_ch_1'  # spot_int_ch_1 , psf_amplitude_ch_1 , snr_ch_1, total_spot_int_ch_1, snr_ch_1
plot_name = 'pRS027'
use_sem = True
show_individual_trajectories = False
show_summary = True
max_percentage_threshold_after_treatment = None  
threshold_percentage_for_runoff = 0.2
ylims = (0, 1.4)
figsize = (8, 4)
# Call the function and plotting
responding_indices_pRS027,frames_experimental_min_recentered_pRS027, intensities_normalized_pRS027, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS027, intensities_normalized_pRS027, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 1
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 10
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 2
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 3
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 4
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251008 Har pRS027_12_61 _10_JF646 6hr Tfx_HarP6_60sDelay_45F_Cell 5
# ...

# %%
substring_in_data_dir = 'pRS038' # pRS027, pRS038 , pRS048
responding_indices_pRS038,frames_experimental_min_recentered_pRS038, intensities_normalized_pRS038, _, _, _, _= HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS038, intensities_normalized_pRS038, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 1
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 10
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 2
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 3
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 4
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 5
# ...

# %%
substring_in_data_dir = 'pRS048' # pRS027, pRS038 , pRS048
responding_indices_pRS048,frames_experimental_min_recentered_pRS048, intensities_normalized_pRS048, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS048, intensities_normalized_pRS048, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 1
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 10
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 2
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 3
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 4
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251014 pRS048_12_61 10_JF646 ON Tfx_HarF6_60sDelay_45F_Cell 5
# ...

# %%
HT.plot_multiple_harringtonine([frames_experimental_min_recentered_pRS027, frames_experimental_min_recentered_pRS038, frames_experimental_min_recentered_pRS038, frames_experimental_min_recentered_pRS048], 
                                [intensities_normalized_pRS027, intensities_normalized_pRS038, intensities_normalized_pRS038, intensities_normalized_pRS048], 
                                harringtonine_frame_index, 
                                responding_indices_list=[responding_indices_pRS027, responding_indices_pRS038, responding_indices_pRS038, responding_indices_pRS048],
                                colors =['green', 'red', 'magenta', 'blue'],
                                legend_labels =['pRS027', 'pRS038 1', 'pRS038 2', 'pRS048'],
                                plot_name='HT_multi', 
                                threshold_percentage_for_runoff =0.25,
                                ylims=(0,1.15),
                                use_sigmoidal_fit = False,
                                figsize= figsize,
                                use_sem = True,
                                show_individual_trajectories=False)
