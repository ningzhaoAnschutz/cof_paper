# %% [markdown]
# # Processing Harringtonine Data
#
# ____

# %%
from pathlib import Path
current_dir = Path().resolve()
from microlive.imports import *
from microlive import microscopy as mi
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import Harringtonine as HT
one_drive_dir
# Out:
# WindowsPath('C:/Users/searsrh/OneDrive - The University of Colorado Denver')

# %%
# Define the parameters
#data_dir = one_drive_dir.joinpath('General - Zhao (NZ) Lab/Zhao lab shared folder/Our papers/Anti-Utag-frankenbody paper/Translation/ALFAtag_JY/HT_Analysis_GUI') # desktop path
#data_dir = one_drive_dir.joinpath('/Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui Analyses/Xbp1 Har')
#data_dir = data_dir.joinpath('Harringtonine')
data_dir = data_dir.joinpath('Users\searsrh\OneDrive - The University of Colorado Denver\Desktop')

results_folder = None
harringtonine_frame_index = 5 # starting to count from 0, so 5 means 6th frame
substring_in_data_dir = 'pRS002' # pNZ212 pNZ231
selected_field = 'spot_int_ch_1'  # spot_int_ch_1 , psf_amplitude_ch_1 , snr_ch_1, total_spot_int_ch_1, snr_ch_1
plot_name = 'pRS002'
use_sem = True
show_individual_trajectories = False
show_summary = True
max_percentage_threshold_after_treatment = None  
threshold_percentage_for_runoff = 0.2
ylims = (0, 1.7)
figsize = (8, 4)
# Call the function and plotting
responding_indices_pRS002,frames_experimental_min_recentered_pRS002, intensities_normalized_pRS002, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS002, intensities_normalized_pRS002, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 20
#      18 figsize = (8, 4)
#      19 # Call the function and plotting
# ---> 20 responding_indices_pRS002,frames_experimental_min_recentered_pRS002, intensities_normalized_pRS002, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
#      21 HT.plot_harringtonine(frames_experimental_min_recentered_pRS002, intensities_normalized_pRS002, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
#
# ...

# %%
substring_in_data_dir = 'pNZ231' # pNZ212 pNZ231
responding_indices_pNZ231,frames_experimental_min_recentered_pNZ231, intensities_normalized_pNZ231, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pNZ231, intensities_normalized_pNZ231, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: /Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui Analyses/Xbp1 Har/results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 9
# subfolder: /Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui Analyses/Xbp1 Har/results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 6
# subfolder: /Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui Analyses/Xbp1 Har/results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 12
# subfolder: /Users/nzlab-la/Library/CloudStorage/OneDrive-TheUniversityofColoradoDenver/General - Zhao (NZ) Lab/Gui Analyses/Xbp1 Har/results_20250204 6hr Tfx pNZ231_pNN010_JF646_HarrintonineF5_1minDelay_30frames_Cell 4-2
# ...

# %%
HT.plot_multiple_harringtonine([frames_experimental_min_recentered_pNZ212, frames_experimental_min_recentered_pNZ231], 
                                [intensities_normalized_pNZ212, intensities_normalized_pNZ231], 
                                harringtonine_frame_index, 
                                responding_indices_list=[responding_indices_pNZ212, responding_indices_pNZ231],
                                colors =['green', 'grey'],
                                legend_labels =['pNZ212', 'pNZ231'],
                                plot_name='HT_multi', 
                                threshold_percentage_for_runoff =0.4,
                                ylims=(0.25,1.15),
                                use_sigmoidal_fit = False,
                                figsize= figsize,
                                use_sem = True,
                                show_individual_trajectories=False)
