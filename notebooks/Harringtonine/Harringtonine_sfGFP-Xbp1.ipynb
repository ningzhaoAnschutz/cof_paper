# %% [markdown]
# # Processing Harringtonine Data
#
# ____

# %%
from pathlib import Path
current_dir = Path().resolve()
from microlive.imports import *
from microlive import microscopy as mi
main_dir = Path().resolve().parent
one_drive_dir = mi.Utilities.get_one_drive_dir()
import Harringtonine as HT
one_drive_dir

# %%
# Define the parameters
    #One Drive file path
#data_dir = one_drive_dir.joinpath(r'C:\Users\searsrh\OneDrive - The University of Colorado Denver\Desktop')

    # External hard drive file path
data_dir = Path (r'D:/Co-translational folding (CoF) paper/4xGFPq-2xmChq/sf_Har')

results_folder = None
harringtonine_frame_index = 5 # starting to count from 0, so 5 means 6th frame
substring_in_data_dir = '20251008' # pRS027 , pRS038
selected_field = 'spot_int_ch_1'  # spot_int_ch_1 , psf_amplitude_ch_1 , snr_ch_1, total_spot_int_ch_1, snr_ch_1
plot_name = '20251008'
use_sem = True
show_individual_trajectories = False
show_summary = True
max_percentage_threshold_after_treatment = None  
threshold_percentage_for_runoff = 0.5
ylims = (0, 1.4)
figsize = (8, 4)
# Call the function and plotting
responding_indices_20251008,frames_experimental_min_recentered_20251008, intensities_normalized_20251008, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_20251008, intensities_normalized_20251008, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)

# %%
substring_in_data_dir = '20251119 pRS027' # pRS027 , pRS038
responding_indices_20251119_pRS027,frames_experimental_min_recentered_20251119_pRS027, intensities_normalized_20251119_pRS027, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_20251119_pRS027, intensities_normalized_20251119_pRS027, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims,)

# %%
substring_in_data_dir = '20251009 Har pRS038' # pRS027 , pRS038
responding_indices_20251009_Har_pRS038,frames_experimental_min_recentered_20251009_Har_pRS038, intensities_normalized_20251009_Har_pRS038, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_20251009_Har_pRS038, intensities_normalized_20251009_Har_pRS038, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 1
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 10
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 2
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 3
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 4
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251009 Har pRS038_012_061 _10_JF646 ON Tfx_HarF6_60sdelay_45F_Cell 5
# ...

# %%
substring_in_data_dir = '20251119 pRS038' # pRS027 , pRS038
responding_indices_20251119_pRS038,frames_experimental_min_recentered_20251119_pRS038, intensities_normalized_20251119_pRS038, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_20251119_pRS038, intensities_normalized_20251119_pRS038, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 1
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 10
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 11
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 2
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 3
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 4
# subfolder: D:\Co-translational folding (CoF) paper\4xGFPq-2xmChq\sf_Har\results_20251119 pRS038_12_61_JF646 ON Tfx_HarF6_60s_95F_Cell 5
# ...

# %%
HT.plot_multiple_harringtonine([frames_experimental_min_recentered_20251008, frames_experimental_min_recentered_20251119_pRS027, frames_experimental_min_recentered_20251009_Har_pRS038, frames_experimental_min_recentered_20251119_pRS038], 
                                [intensities_normalized_20251008, intensities_normalized_20251119_pRS027, intensities_normalized_20251009_Har_pRS038, intensities_normalized_20251119_pRS038], 
                                harringtonine_frame_index, 
                                responding_indices_list=[responding_indices_20251008, responding_indices_20251119_pRS027, responding_indices_20251009_Har_pRS038, responding_indices_20251119_pRS038],
                                colors =['green', 'blue', 'red', 'orange'],
                                legend_labels =['pRS027 1', 'pRS027 2', 'pRS038 1', 'pRS038 2'],
                                plot_name='HT_multi',
                                threshold_percentage_for_runoff =0.3,
                                ylims=(0,1.15),
                                use_sigmoidal_fit = False,
                                figsize= figsize,
                                use_sem = True,
                                show_individual_trajectories=False)

# %%
substring_in_data_dir = 'pRS032' # pRS045 , pRS032
responding_indices_pRS032,frames_experimental_min_recentered_pRS032, intensities_normalized_pRS032, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS032, intensities_normalized_pRS032, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# No dataframes found with frame number greater than 10 frames.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 substring_in_data_dir = 'pRS032' # pRS045 , pRS032
# ----> 2 responding_indices_pRS032,frames_experimental_min_recentered_pRS032, intensities_normalized_pRS032, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
#       3 HT.plot_harringtonine(frames_experimental_min_recentered_pRS032, intensities_normalized_pRS032, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
#
# ValueError: not enough values to unpack (expected 7, got 3)

# %%
substring_in_data_dir = 'pRS045' # pRS045 , pRS032
responding_indices_pRS045,frames_experimental_min_recentered_pRS045, intensities_normalized_pRS045, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
HT.plot_harringtonine(frames_experimental_min_recentered_pRS045, intensities_normalized_pRS045, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
# Out:
# List of processed dataframes:
# No dataframes found with frame number greater than 10 frames.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 substring_in_data_dir = 'pRS045' # pRS045 , pRS032
# ----> 2 responding_indices_pRS045,frames_experimental_min_recentered_pRS045, intensities_normalized_pRS045, _, _, _, _ = HT.process_HT_data(data_dir, harringtonine_frame_index, substring_in_data_dir, selected_field, use_sem, show_summary, max_percentage_threshold_after_treatment, )
#       3 HT.plot_harringtonine(frames_experimental_min_recentered_pRS045, intensities_normalized_pRS045, harringtonine_frame_index, show_runoff_time = True, plot_name=plot_name,threshold_percentage_for_runoff=threshold_percentage_for_runoff,figsize=figsize,ylims=ylims)
#
# ValueError: not enough values to unpack (expected 7, got 3)

# %%
HT.plot_multiple_harringtonine([frames_experimental_min_recentered_pRS032, frames_experimental_min_recentered_pRS045], 
                                [intensities_normalized_pRS032, intensities_normalized_pRS045], 
                                harringtonine_frame_index, 
                                responding_indices_list=[responding_indices_pRS032, responding_indices_pRS045],
                                colors =['green', 'red'],
                                legend_labels =['pRS032', 'pRS045'],
                                plot_name='HT_multi',
                                threshold_percentage_for_runoff =0,
                                ylims=(0,1.15),
                                use_sigmoidal_fit = False,
                                figsize=(6, 4),
                                use_sem = True,
                                show_individual_trajectories=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 HT.plot_multiple_harringtonine([frames_experimental_min_recentered_pRS032, frames_experimental_min_recentered_pRS045],
#       2                                 [intensities_normalized_pRS032, intensities_normalized_pRS045],
#       3                                 harringtonine_frame_index,
#       4                                 responding_indices_list=[responding_indices_pRS032, responding_indices_pRS045],
#       5                                 colors =['green', 'red'],
#       6                                 legend_labels =['pRS032', 'pRS045'],
#       7                                 plot_name='HT_multi',
#       8                                 threshold_percentage_for_runoff =0,
#       9                                 ylims=(0,1.15),
# ...
